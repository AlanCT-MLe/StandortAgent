# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from pathlib import Path

# %%
json_path = Path("data") / "municipalities.json"
json_df = pd.read_json(json_path,orient="records")

# %%
json_df.head()
# Out:
#                                             _hinweis  \
# 0  synthetisch / vereinfacht, Stand 2026-06, kein...
# 1  synthetisch / vereinfacht, Stand 2026-06, kein...
# 2  synthetisch / vereinfacht, Stand 2026-06, kein...
# 3  synthetisch / vereinfacht, Stand 2026-06, kein...
# 4  synthetisch / vereinfacht, Stand 2026-06, kein...
#
#                                       municipalities
# 0  {'gemeinde': 'Wien (1., Innere Stadt)', 'bunde...
# 1  {'gemeinde': 'Wien (7., Neubau)', 'bundesland'...
# 2  {'gemeinde': 'Wien (10., Favoriten)', 'bundesl...
# 3  {'gemeinde': 'Graz (Innere Stadt)', 'bundeslan...
# 4  {'gemeinde': 'Graz (Lend)', 'bundesland': 'Ste...

# %%
csv_path = Path("data") / "municipalities.csv"
df = pd.read_csv(csv_path)

# %%
df.head(20)
# Out:
#                      gemeinde        bundesland  einwohner  \
# 0     Wien (1., Innere Stadt)              Wien      16000
# 1           Wien (7., Neubau)              Wien      30000
# 2       Wien (10., Favoriten)              Wien     210000
# 3         Graz (Innere Stadt)        Steiermark      28000
# 4                 Graz (Lend)        Steiermark      32000
# 5            Leoben (Zentrum)        Steiermark      24000
# 6           Linz (Stadtmitte)    Oberösterreich      22000
# 7               Linz (Urfahr)    Oberösterreich      28000
# 8           Wels (Innenstadt)    Oberösterreich      21000
# 9         Innsbruck (Zentrum)             Tirol      18000
# 10         Innsbruck (Wilten)             Tirol      16000
# 11        Salzburg (Altstadt)          Salzburg      12000
# 12           Salzburg (Lehen)          Salzburg      20000
# 13    Klagenfurt (Innenstadt)           Kärnten      17000
# 14          Villach (Zentrum)           Kärnten      15000
# ...
